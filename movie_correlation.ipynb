# %%
#import libraires 
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure 

# %matplotlib inline
matplotlib.rcParams ['figure.figsize'] = (12,8) #adjusts the configuration of the plots

# %%
movie_df= pd.read_csv('..\data\movies.csv')

# %%
#exploring the data

movie_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#findidng missing data

for col in movie_df.columns:
    pct_missing= np.mean(movie_df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#data types for the column
movie_df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#changing data type
#have to use this extension due to the presence of NaN values in the data
from pandas.api.extensions import register_extension_dtype
from pandas.api.extensions import ExtensionDtype
@register_extension_dtype
class MyExtensionDtype(ExtensionDtype):pass

# %%
movie_df['budget'] =movie_df['budget'].astype('Int64')

# %%
movie_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
movie_df['gross'] =movie_df['gross'].astype('Int64')

# %%
movie_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#movie_df['released']=movie_df['released'].astype(str).str[]

#movie_df['releaseddate_new'] = movie_df['released'].str.split(',').str[0]
#movie_df['releasedyear_new'] = movie_df['released'].str.split('(').str[0]

#movie_df['released_year_new'] = movie_df['releasedyear_new'].str.split(',').str[1]
#movie_df

# %%
movie_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
del movie_df["year_correct"]

# %%
movie_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
movie_df['released_place'] = movie_df['released'].str.split('(').str[1]
movie_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#movie_df['released_place_new'] = movie_df['released_place'].str.rstrip(')')
#movie_df

# %%
del movie_df["released_place"]
movie_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
movie_df.rename(columns={'released_new': 'released_date', 'released_year_new': 'released_year', 'released_place_new':'released_region'}, inplace=True)
movie_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
del movie_df["released"]
del movie_df["year"]
movie_df.head()
# Out:
#                                              name rating      genre  score  \
# 0                                     The Shining      R      Drama    8.4
# 1                                 The Blue Lagoon      R  Adventure    5.8
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action    8.7
# 3                                       Airplane!     PG     Comedy    7.7
# 4                                      Caddyshack      R     Comedy    7.3
#
#        votes         director                   writer            star  \
# 0   927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2  1200000.0   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3   221000.0     Jim Abrahams             Jim Abrahams     Robert Hays
# 4   108000.0     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
#           country    budget      gross             company  runtime
# ...

# %%
movie_df['votes'] =movie_df['votes'].astype('Int64')
movie_df.head()
# Out:
#                                              name rating      genre  score  \
# 0                                     The Shining      R      Drama    8.4
# 1                                 The Blue Lagoon      R  Adventure    5.8
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action    8.7
# 3                                       Airplane!     PG     Comedy    7.7
# 4                                      Caddyshack      R     Comedy    7.3
#
#      votes         director                   writer            star  \
# 0   927000  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    65000   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2  1200000   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3   221000     Jim Abrahams             Jim Abrahams     Robert Hays
# 4   108000     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
#           country    budget      gross             company  runtime
# ...

# %%
movie_df.sort_values(by=['gross'], inplace=False, ascending=False)  #sorting by highest grossing movies
# Out:
#                                             name rating   genre  score  \
# 5445                                      Avatar  PG-13  Action    7.8
# 7445                           Avengers: Endgame  PG-13  Action    8.4
# 3045                                     Titanic  PG-13   Drama    7.8
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action    7.8
# 7244                      Avengers: Infinity War  PG-13  Action    8.4
# ...                                          ...    ...     ...    ...
# 7663                                More to Life    NaN   Drama    3.1
# 7664                                 Dream Round    NaN  Comedy    4.7
# 7665                               Saving Mbango    NaN   Drama    5.7
# 7666                                It's Just Us    NaN   Drama    NaN
# 7667                                   Tee em el    NaN  Horror    5.7
#
#         votes       director              writer               star  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
movie_df['company'].drop_duplicates().sort_values(ascending=False) #this shows distinctive values in a column super important!
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 6412                             iDeal Partners Film Fund
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 524                             Zupnik-Curtis Enterprises
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 6222                        Zentropa International Norway
# 3368                              Zentropa Entertainments
# 535                                  Zenith Entertainment
# 5180                                      Zazen Produções
# 3193                                          ZapPictures
# ...

# %%
movie_df.head()
# Out:
#                                              name rating      genre  score  \
# 0                                     The Shining      R      Drama    8.4
# 1                                 The Blue Lagoon      R  Adventure    5.8
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action    8.7
# 3                                       Airplane!     PG     Comedy    7.7
# 4                                      Caddyshack      R     Comedy    7.3
#
#      votes         director                   writer            star  \
# 0   927000  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    65000   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2  1200000   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3   221000     Jim Abrahams             Jim Abrahams     Robert Hays
# 4   108000     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
#           country    budget      gross             company  runtime
# ...

# %%
#hypothesis:
#budget have high correlation
#more bigger companys will have high correlation

# %%
#comparing budgest vs gross revenue 

plt.scatter(x=movie_df['budget'], y=movie_df['gross'])
plt.title('Budget vs Gross')
plt.xlabel('Gross')
plt.ylabel('Budget')
plt.show()

# %%
#plot the budget vs gross using seaborn \
movie_df['budget'] =movie_df['budget'].astype('float64')
movie_df['gross'] =movie_df['gross'].astype('float64')

sns.regplot(x='budget', y='gross', data=movie_df, scatter_kws={'color':'red'}, line_kws={'color':'blue'})

# %%
#looking at correlation 
#there are different methods of correlation: pearson, kendall, spearman 

movie_df.corr(method='pearson')
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
#high correlation between budget and gross- hypothesis proved!

# %%
correlation_matrix=movie_df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)


plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
#to have a coorelation matrix like the above for company, it needs to be a numeric value and not a string
#following will show hhow we can assign a unique identifier to the names of the company so that they are numeric value

# %%
movie_df['name'] =movie_df['name'].astype('object')

# %%
movie_df['genre'] =movie_df['genre'].astype('object')

# %%
df_numerized = movie_df

for col_name in df_numerized.columns: 
    if (df_numerized[col_name].dtype =='object'):
            df_numerized[col_name] = df_numerized[col_name].astype('category')
            df_numerized[col_name] = df_numerized[col_name].cat.codes

# %%
df_numerized.head()
# Out:
#    name  rating  genre  score    votes  director  writer  star  country  \
# 0  6587       6      6    8.4   927000      2589    4014  1047       54
# 1  5573       6      1    5.8    65000      2269    1632   327       55
# 2  5142       4      0    8.7  1200000      1111    2567  1745       55
# 3   286       4      4    7.7   221000      1301    2000  2246       55
# 4  1027       6      4    7.3   108000      1054     521   410       55
#
#        budget        gross  company  runtime
# 0  19000000.0   46998772.0     2319    146.0
# 1   4500000.0   58853106.0      731    104.0
# 2  18000000.0  538375067.0     1540    124.0
# 3   3500000.0   83453539.0     1812     88.0
# 4   6000000.0   39846344.0     1777     98.0

# %%
movie_df.head()
# Out:
#    name  rating  genre  score    votes  director  writer  star  country  \
# 0  6587       6      6    8.4   927000      2589    4014  1047       54
# 1  5573       6      1    5.8    65000      2269    1632   327       55
# 2  5142       4      0    8.7  1200000      1111    2567  1745       55
# 3   286       4      4    7.7   221000      1301    2000  2246       55
# 4  1027       6      4    7.3   108000      1054     521   410       55
#
#        budget        gross  company  runtime
# 0  19000000.0   46998772.0     2319    146.0
# 1   4500000.0   58853106.0      731    104.0
# 2  18000000.0  538375067.0     1540    124.0
# 3   3500000.0   83453539.0     1812     88.0
# 4   6000000.0   39846344.0     1777     98.0

# %%
correlation_matrix=df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)


plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#               name    rating     genre     score     votes  director  \
# name      1.000000 -0.008069  0.016355  0.017097  0.013088  0.009079
# rating   -0.008069  1.000000  0.072423 -0.001314  0.033225  0.019483
# genre     0.016355  0.072423  1.000000  0.027965 -0.145307 -0.015258
# score     0.017097 -0.001314  0.027965  1.000000  0.409182  0.009559
# votes     0.013088  0.033225 -0.145307  0.409182  1.000000  0.000260
# director  0.009079  0.019483 -0.015258  0.009559  0.000260  1.000000
# writer    0.009081 -0.005921  0.006567  0.019416  0.000892  0.299067
# star      0.006472  0.013405 -0.005477 -0.001609 -0.019282  0.039234
# country  -0.010737  0.081244 -0.037615 -0.133348  0.073625  0.017490
# budget    0.023970 -0.176002 -0.356564  0.076254  0.442429 -0.012272
# gross     0.005533 -0.107339 -0.235650  0.186258  0.630757 -0.014441
# company   0.009211 -0.032943 -0.071067  0.001030  0.133204  0.004404
# runtime   0.010392  0.062145 -0.052711  0.399451  0.309212  0.017624
#
# ...

# %%
correlation_mat=df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name      name        1.000000
#           rating     -0.008069
#           genre       0.016355
#           score       0.017097
#           votes       0.013088
#           director    0.009079
#           writer      0.009081
#           star        0.006472
#           country    -0.010737
#           budget      0.023970
#           gross       0.005533
#           company     0.009211
#           runtime     0.010392
# rating    name       -0.008069
#           rating      1.000000
#           genre       0.072423
#           score      -0.001314
#           votes       0.033225
#           director    0.019483
#           writer     -0.005921
#           star        0.013405
#           country     0.081244
#           budget     -0.176002
#           gross      -0.107339
#           company    -0.032943
#           runtime     0.062145
# genre     name        0.016355
#           rating      0.072423
#           genre       1.000000
#           score       0.027965
# ...

# %%
sorted_pairs=corr_pairs.sort_values()

# %%
sorted_pairs
# Out:
# budget    genre      -0.356564
# genre     budget     -0.356564
#           gross      -0.235650
# gross     genre      -0.235650
# rating    budget     -0.176002
# budget    rating     -0.176002
# genre     votes      -0.145307
# votes     genre      -0.145307
# country   score      -0.133348
# score     country    -0.133348
# gross     rating     -0.107339
# rating    gross      -0.107339
# country   runtime    -0.078412
# runtime   country    -0.078412
# genre     company    -0.071067
# company   genre      -0.071067
# runtime   genre      -0.052711
# genre     runtime    -0.052711
# writer    budget     -0.039451
# budget    writer     -0.039451
# genre     country    -0.037615
# country   genre      -0.037615
# rating    company    -0.032943
# company   rating     -0.032943
# writer    gross      -0.023519
# gross     writer     -0.023519
# budget    star       -0.019589
# star      budget     -0.019589
# votes     star       -0.019282
# star      votes      -0.019282
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# votes     gross       0.630757
# gross     votes       0.630757
# budget    gross       0.740395
# gross     budget      0.740395
# name      name        1.000000
# writer    writer      1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# director  director    1.000000
# votes     votes       1.000000
# score     score       1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
#I wanted to see if company has any sort of correlation. And as we can see there isn't much 
#votes and budges has more corrleation to gross earnings
